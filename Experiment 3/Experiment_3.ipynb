# %% [markdown]
# # Experiment 3: Stemming, Lemmatization, and Regular Expressions
#
# This notebook demonstrates word normalization techniques including suffix-stripping via the Porter Stemmer, morphological reduction via the WordNet Lemmatizer (default and POS-aware), and structured information extraction using Regular Expressions (Regex).

# %% [markdown]
# ## 1. Environment Setup and Library Imports
#
# Import required packages (`nltk`, `re`, `pandas`) and instantiate the stemmer and lemmatizer models.

# %%
import re
import pandas as pd
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import wordnet

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ## Experiment 3.1: Stemming Using Porter Stemmer
#
# Apply the Porter Stemming algorithm to the specified word list to observe rule-based suffix truncation.

# %%
words_to_stem = [
    'playing', 'played', 'plays', 
    'studies', 'studying', 
    'connected', 'connection', 
    'computers'
]

stem_data = []
for word in words_to_stem:
    stem_data.append({
        'Original Word': word,
        'Porter Stem': stemmer.stem(word)
    })

df_stemming = pd.DataFrame(stem_data)
df_stemming
# Out:
#   Original Word Porter Stem
# 0       playing        play
# 1        played        play
# 2         plays        play
# 3       studies       studi
# 4      studying       studi
# 5     connected     connect
# 6    connection     connect
# 7     computers      comput

# %% [markdown]
# ## Experiment 3.2: Lemmatization Using WordNet Lemmatizer
#
# Perform morphological lemmatization on inflected and irregular word forms with default (noun) and POS-aware mappings.

# %%
words_to_lemmatize = [
    'cats', 'dogs', 'running', 'runs', 'ran', 
    'studies', 'studying', 'better', 'children', 
    'mice', 'went', 'ate', 'leaves', 'caring'
]

pos_mapping = {
    'cats': wordnet.NOUN,
    'dogs': wordnet.NOUN,
    'running': wordnet.VERB,
    'runs': wordnet.VERB,
    'ran': wordnet.VERB,
    'studies': wordnet.VERB,
    'studying': wordnet.VERB,
    'better': wordnet.ADJ,
    'children': wordnet.NOUN,
    'mice': wordnet.NOUN,
    'went': wordnet.VERB,
    'ate': wordnet.VERB,
    'leaves': wordnet.NOUN,
    'caring': wordnet.VERB
}

lemma_data = []
for word in words_to_lemmatize:
    default_lemma = lemmatizer.lemmatize(word)
    pos_tag = pos_mapping[word]
    pos_lemma = lemmatizer.lemmatize(word, pos=pos_tag)
    lemma_data.append({
        'Original Word': word,
        'Assigned POS': pos_tag,
        'Default Lemma (Noun)': default_lemma,
        'POS-Aware Lemma': pos_lemma
    })

df_lemmatization = pd.DataFrame(lemma_data)
df_lemmatization
# Out:
#    Original Word Assigned POS Default Lemma (Noun) POS-Aware Lemma
# 0           cats            n                  cat             cat
# 1           dogs            n                  dog             dog
# 2        running            v              running             run
# 3           runs            v                  run             run
# 4            ran            v                  ran             run
# 5        studies            v                study           study
# 6       studying            v             studying           study
# 7         better            a               better            good
# 8       children            n                child           child
# 9           mice            n                mouse           mouse
# 10          went            v                 went              go
# 11           ate            v                  ate             eat
# 12        leaves            n                 leaf            leaf
# 13        caring            v               caring            care

# %% [markdown]
# ## Experiment 3.3: Information Extraction Using Regular Expressions (Regex)
#
# Extract email addresses, URLs, mobile numbers, hashtags, and mentions from the provided workshop announcement text.

# %%
input_text = """Welcome to the Natural Language Processing workshop! For more information, visit https://www.nlpworkshop.com or www.python.org. You can contact the coordinator at nlpworkshop@gmail.com or support@python.org. For registration, call +91-9876543210 or 9123456789. Follow us on social media @NLPWorkshop and @PythonLearner. Share your experience using #NLP, #Python, and #MachineLearning. You can also visit https://github.com/NLPWorkshop for the latest updates."""

emails = re.findall(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b', input_text)
raw_urls = re.findall(r'https?://[^\s,]+|www\.[^\s,]+(?<!\.)', input_text)
urls = [u.rstrip('.') for u in raw_urls]
mobile_numbers = re.findall(r'\+91-\d{10}|\b\d{10}\b', input_text)
hashtags = re.findall(r'#\w+', input_text)
mentions = re.findall(r'(?<!\S)@\w+', input_text)

print(f"1. Email Addresses ({len(emails)}):")
for item in emails:
    print(f"   - {item}")

print(f"\n2. URLs ({len(urls)}):")
for item in urls:
    print(f"   - {item}")

print(f"\n3. Mobile Numbers ({len(mobile_numbers)}):")
for item in mobile_numbers:
    print(f"   - {item}")

print(f"\n4. Hashtags ({len(hashtags)}):")
for item in hashtags:
    print(f"   - {item}")

print(f"\n5. Mentions ({len(mentions)}):")
for item in mentions:
    print(f"   - {item}")
# Out:
# 1. Email Addresses (2):
#    - nlpworkshop@gmail.com
#    - support@python.org
#
# 2. URLs (3):
#    - https://www.nlpworkshop.com
#    - www.python.org
#    - https://github.com/NLPWorkshop
#
# 3. Mobile Numbers (2):
#    - +91-9876543210
#    - 9123456789
#
# 4. Hashtags (3):
#    - #NLP
#    - #Python
#    - #MachineLearning
#
# 5. Mentions (2):
#    - @NLPWorkshop
#    - @PythonLearner
